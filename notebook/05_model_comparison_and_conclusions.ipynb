# %% [markdown]
# <a href="https://colab.research.google.com/github/sngillard/student-outcome-classification/blob/main/notebook/05_model_comparison_and_conclusions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Model Comparison and Conclusion:
#
# * The gradient boosting classifier model achieved a *slightly* higher cross-validation accuracy (about 0.78) compared to the tuned logistic regression model (about 0.77).
# * Logistic regression provides better interpretability and a faster training time.
# * Gradient boosting showed improved predictive ability by non-linear relationships.
# * Results can be reproduced, so minor variations can occur each time the model is run.
